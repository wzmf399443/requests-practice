# %%
import requests

host = "https://www.travel.taipei/open-api"
lang = "en"
resp = requests.get(f"{host}/{lang}/Attractions/All", params={"page":"1"}, headers={"accept":"application/json"})
print(resp.json())
# Out:
# {'total': 413, 'data': [{'id': 567, 'name': 'Museum of Medical Humanities, NTU', 'name_zh': None, 'open_status': 1, 'introduction': 'The earliest building of the Museum of Medical Humanities, initially belonging to the medical school of Taihoku Imperial University, was completed in 1907 by Kondo Juro under the Japanese colonial rule. The century-old main structure was unveiled later in 1913 and is largely still preserved today, thanks to frequent restoration efforts. Initially used to house classrooms and an administrative center, the main structure grew into a national hub of medical research, a fortress of medical education reform, a site of medical humanities education and, in 2008, a museum. In addition to permanent exhibits such as &ldquo;A New Born&rdquo;, &ldquo;The Peopling of Taiwan&rdquo; and &ldquo;Taiwanese People&rsquo;s Struggle against Diseases&rdquo;, the Museum offers special exhibits every six months to explore the impact of medical studies. It also displays exhibit
# ...
